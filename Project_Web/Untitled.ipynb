# %%
import pandas as pd
import openpyxl
# اسم ملف الإكسل
file_path = 'dataSetLabtupMassionLarning.xlsx'
# اقرأ ملف الإكسل
df = pd.read_excel(file_path)

# عرض أول 10 سجلات
df.head(10)
# Out:
#    DateOfPurchase Company    Core   Ryzen Suffix  Generation    GPUType  \
# 0            2016      HP       0  Ryzen7     HQ           8   Built-in
# 1            2016  Lenovo  COREI3  Ryzen3      U           3   Built-in
# 2            2016      HP  COREI3       0      U           6    960MX2G
# 3            2016      HP  COREI3       0      U           4   Built-in
# 4            2016      HP  COREI3       0      U           3   Built-in
# 5            2018   Apple  COREI3       0      U           4   Built-in
# 6            2018   Apple  COREI7       0      U          10  GTX10504G
# 7            2018    Asus  COREI5       0      U           6    960MX2G
# 8            2018      HP  COREI3       0      H           3   Built-in
# 9            2018      HP  COREI5       0      U           5    960MX2G
#
#    RAMSize  HardType  HardSize        Material ColoreKeyboard  ScreenSize  \
# 0        8       HDD       256     CarbonFiber            RGB        15.6
# 1        4       HDD       256     CarbonFiber            RGB        11.0
# 2        8       HDD       256         Plastic             NO        15.6
# 3        4       HDD       256         Plastic             NO        14.0
# 4        4       HDD       512     CarbonFiber             NO        15.6
# 5        4       HDD       256           Metal             NO        11.0
# 6        8  SSD SATA       512  StainlessSteel            RGB        11.0
# 7        8       HDD       256           Metal             NO        15.6
# 8        4  SSD SATA      1024        Aluminum             NO        15.6
# 9        4   SSD M.2       256     CarbonFiber             NO        15.6
#
#    Resolution Quality TypeScreen condition  price
# 0          90      2K        IPS      Used    400
# 1          60      HD        IPS      Used    200
# 2          60      HD        IPS      Used    300
# 3          60      HD       OLED      Used    300
# 4          60      HD       OLED       New    800
# 5          60      HD       OLED       New    600
# 6         165      8K        IPS   Openbox    899
# 7          60      HD        IPS      Used    360
# 8          90      HD       OLED       New    200
# 9          60      HD       OLED      Used    450

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# اسم ملف الإكسل
file_path = 'dataSetLabtupMassionLarning.xlsx'

# اقرأ ملف الإكسل
df = pd.read_excel(file_path)

# تحويل القيم العددية في العمود "Company" إلى نصوص
df['Core'] = df['Core'].astype(str)
df['Ryzen'] = df['Ryzen'].astype(str)

# قائمة بأسماء الأعمدة التي تحتوي على قيم نصية وتحتاج إلى تحويلها إلى أرقام
text_columns = [ 'Company','Core', 'Ryzen', 'Suffix', 'GPUType', 'HardType', 'Material', 'ColoreKeyboard', 'Quality', 'TypeScreen', 'condition']

label_encoder = LabelEncoder()

# تحويل الأعمدة النصية إلى أرقام
for column in text_columns:
    df[column] = label_encoder.fit_transform(df[column])

# حفظ البيانات المحدثة في ملف Excel جديد
output_file_path = 'newlearningmasheen4.xlsx'
df.to_excel(output_file_path, index=False)

# %%
file_path = 'newlearningmasheen4.xlsx'

# اقرأ ملف الإكسل
df = pd.read_excel(file_path)
df.head(10)
# Out:
#    DateOfPurchase  Company  Core  Ryzen  Suffix  Generation  GPUType  RAMSize  \
# 0            2016        4     0      3       2           8        1        8
# 1            2016        5     1      1       5           3        1        4
# 2            2016        4     1      0       5           6        0        8
# 3            2016        4     1      0       5           4        1        4
# 4            2016        4     1      0       5           3        1        4
# 5            2018        1     1      0       5           4        1        4
# 6            2018        1     3      0       5          10        2        8
# 7            2018        2     2      0       5           6        0        8
# 8            2018        4     1      0       0           3        1        4
# 9            2018        4     2      0       5           5        0        4
#
#    HardType  HardSize  Material  ColoreKeyboard  ScreenSize  Resolution  \
# 0         0       256         1               2        15.6          90
# 1         0       256         1               2        11.0          60
# 2         0       256         3               1        15.6          60
# 3         0       256         3               1        14.0          60
# 4         0       512         1               1        15.6          60
# 5         0       256         2               1        11.0          60
# 6         2       512         4               2        11.0         165
# 7         0       256         2               1        15.6          60
# 8         2      1024         0               1        15.6          90
# 9         1       256         1               1        15.6          60
#
#    Quality  TypeScreen  condition  price
# 0        0           0          2    400
# 1        4           0          2    200
# 2        4           0          2    300
# 3        4           1          2    300
# 4        4           1          0    800
# 5        4           1          0    600
# 6        2           0          1    899
# 7        4           0          2    360
# 8        4           1          0    200
# 9        4           1          2    450

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# اختيار الميزات
features = df.drop('price', axis=1)

# اختيار الهدف
target = df['price']
# قسم البيانات إلى مجموعات تدريب واختبار
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# إنشاء نموذج الانحدار الخطي
model = LinearRegression()

# تدريب النموذج على البيانات
model.fit(X_train, y_train)
# توقع أسعار اللابتوب باستخدام النموذج
# توقع أسعار اللابتوب باستخدام النموذج ومجموعة الاختبار
predicted_prices = model.predict(X_test)


predicted_prices
# Out:
# array([ 321.86612105,  421.19460951,  425.68363926,  454.4873229 ,
#         422.28489887,  782.58843762,  356.24329539,  369.45545157,
#         308.6136804 ,  443.22954429,  632.44527223,  437.47936785,
#         454.55438729,  415.88514271, 1155.32584315,  600.14044214,
#         959.54128013,  508.67350209,  353.65310653,  592.77123739,
#         401.5551436 ,  535.17344655,  482.14563384,  682.26560955,
#         616.52016548,  729.28865486,  493.99193374,  357.02048918,
#         454.0939021 ,  616.19464351,  605.14295341,  297.44196558,
#         505.00191407,  711.65618998,  346.00853882,  371.70042501,
#         437.49145404,  628.45167278,  357.99819853,  502.38354354,
#         550.60056627,  447.42155533, 1099.86578511,  362.02662466,
#         783.39104629,  943.34751129,  457.43345038,  575.00682472,
#         468.42207847,  450.28775486,  339.0752145 ,  309.74298868,
#        1206.11724361,  312.98037871,  469.19562746,  398.97172203,
#         374.0629412 ,  422.02602876,  696.91837563,  441.64900669,
#         641.03740878,  521.3195064 ,  338.37708766,  584.06080406,
#         599.7006086 ,  528.27512321,  553.88379793,  824.94829823,
#        1126.1398948 ,  647.00374299,  866.13558059,  819.90221838,
#         297.80741788,  485.17598568,  865.8802414 ,  621.35637152,
#         931.77576412,  820.90282142,  401.81908645,  607.10111119,
#         614.46616799,  722.41845248,  416.92893976,  668.85636847,
#         442.79691295,  255.74455085,  463.62641692,  671.34091661,
#         389.42928754,  406.73620365,  792.46360968,  601.34517195,
#         471.7904757 ,  445.67123309,  360.80763938, 1087.95427944,
#         640.58632428,  349.53243705,  625.58017569,  598.99925248,
#         433.02234532,  313.06774296,  238.20298211, 1073.50897708,
#         303.15813957,  691.60403996,  758.57827151,  246.77108914,
#         237.40356559,  332.21810288,  898.75073954,  330.96380367,
#         268.646287  ,  480.01050428,  687.80744743,  282.14510658,
#         220.48651485,  453.92503258,  564.89706096,  343.53640435,
#         653.58553732,  487.75605377, 1472.65113141,  316.64613987,
#         545.65187048,  268.06173273,  407.51461707,  567.5334996 ,
#         297.81148909,  498.54523911,  284.78503947,  574.50932705,
#         359.70558899,  497.01098565,  573.09550598,  820.88650978,
#         380.99744906,  418.6132391 ,  412.02734624,  528.11209849,
#         355.63204432,  366.4245848 ,  746.91431585,  598.32322462,
#         310.74077542,  648.00338656,  323.0363242 , 1358.2190681 ,
#         405.53710887,  515.70356176,  311.88475072,  331.39855802,
#         613.41224238,  591.02354365,  345.2891085 ,  442.07085956,
#         352.55774267,  467.32368559,  526.4904024 ,  623.03863697,
#         555.20498096,  338.80457005, 1173.17736061,  531.91923562,
#         283.79305688,  863.98564731,  256.71920018,  460.76890639,
#         545.87742341,  498.11202058,  346.24570479,  560.88994361,
#         729.85309242,  356.03949985,  413.41396772,  794.59107399,
#         334.84884591,  604.6695036 ,  344.28340556,  582.81541389,
#         464.33421271,  428.44498756,  654.7695754 ,  378.57005794,
#         709.60055903,  674.06201022,  253.43024983,  316.31848538,
#        1157.03409593,  493.63953748,  325.24424411,  678.09413196,
#         287.31524221,  472.91015677,  345.31698741,  237.84533041,
#         546.79692679,  568.34649555,  461.79774135, 1243.90522189,
#         394.57475965,  568.34649555,  410.41185034,  432.77453996,
#         900.34032482,  505.49717223,  567.25881835,  634.40084659,
#         597.56709751,  636.70899097,  409.78815772,  456.89519942,
#         324.77628692,  311.97040298,  711.65618998,  236.74996654,
#         357.55498794,  513.8789994 ,  443.44404349,  387.9056525 ,
#        1058.32172639,  577.99478896])

# %%
from sklearn.metrics import mean_squared_error

# توقع أسعار اللابتوب باستخدام النموذج ومجموعة الاختبار
predicted_prices = model.predict(X_test)

# حساب متوسط مربعات الخطأ (MSE)
mse = mean_squared_error(y_test, predicted_prices)

# طباعة قيمة MSE
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 32324.589110859724

# %%
# استيراد المكتبات
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

file_path = 'newlearningmasheen4.xlsx'
# اقرأ ملف الإكسل
data = pd.read_excel(file_path)
# اختيار الميزات والهدف
features = data[['Core','GPUType','RAMSize', 
                 'HardType', 'HardSize', 'ScreenSize',
                 'Quality', 'condition']]
target = data['price']

# تقسيم البيانات إلى مجموعات تدريب واختبار
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# بناء النموذج وتدريبه
model = LinearRegression()
model.fit(X_train, y_train)

# توقع أسعار اللابتوب باستخدام النموذج ومجموعة الاختبار
predicted_prices = model.predict(X_test)

# حساب متوسط مربعات الخطأ (MSE)
mse = mean_squared_error(y_test, predicted_prices)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 37087.02630795335

# %%
def predict_laptop_price(core, gpu_type, ram_size, hard_type, hard_size, screen_size, quality, condition):
    # تحضير البيانات كمدخلات للنموذج
    laptop_features = [[core, gpu_type, ram_size, hard_type, hard_size, screen_size, quality, condition]]

    # توقع سعر اللابتوب باستخدام النموذج
    predicted_price = model.predict(laptop_features)

    return predicted_price[0]
# المواصفات المذكورة
laptop_core = 5  # Core i5
laptop_gpu_type = 3  # NIVIDIA Ge force GT 750 with 4 GB
laptop_ram_size = 8  # 8 GB DDR3
laptop_hard_type = 0  # HARD SSD
laptop_hard_size = 500  # 500GB
laptop_screen_size = 15.6  # لم يتم تقديم حجم الشاشة في المواصفات
laptop_quality = 2.7  # Good
laptop_condition =2  # used
predicted_price = predict_laptop_price(laptop_core, laptop_gpu_type, laptop_ram_size, laptop_hard_type, laptop_hard_size, laptop_screen_size, laptop_quality, laptop_condition)
print("Predicted Laptop Price:", predicted_price)
# Out:
# Predicted Laptop Price: 499.14834358771844
# C:\Users\KZ-WORK\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
